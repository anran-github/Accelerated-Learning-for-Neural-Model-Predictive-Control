# %% [markdown]
# *Data Summary*
#
# - We normized three losses between 0 to 1 by dividing the values of the first iteration training.

# %% [markdown]
# 1. **Low Level Noise**
#
# | Weights         | Performance Index       |
# |------------------|-------------------------|
# | **1, 0, 0** (no noise)     | **107.14547729492188**               |
# | **1, 0, 0**      | **162.6478729248047**               |
# | **0.05, 0.9, 0.05**    | **71.6671371459961**               |
# | **0.25, 0.7, 0.05**    | **89.2303695678711**               |
